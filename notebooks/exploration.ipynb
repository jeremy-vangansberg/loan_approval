# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('SBAnational.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Name               899150 non-null  object
#  2   City               899134 non-null  object
#  3   State              899150 non-null  object
#  4   Zip                899164 non-null  int64
#  5   Bank               897605 non-null  object
#  6   BankState          897598 non-null  object
#  7   NAICS              899164 non-null  int64
#  8   ApprovalDate       899164 non-null  object
#  9   ApprovalFY         899164 non-null  object
#  10  Term               899164 non-null  int64
#  11  NoEmp              899164 non-null  int64
#  12  NewExist           899028 non-null  float64
#  13  CreateJob          899164 non-null  int64
#  14  RetainedJob        899164 non-null  int64
#  15  FranchiseCode      899164 non-null  int64
#  16  UrbanRural         899164 non-null  int64
#  17  RevLineCr          894636 non-null  object
#  18  LowDoc             896582 non-null  object
#  19  ChgOffDate         162699 non-null  object
#  20  DisbursementDate   896796 non-null  object
#  21  DisbursementGross  899164 non-null  object
#  22  BalanceGross       899164 non-null  object
#  23  MIS_Status         897167 non-null  object
#  24  ChgOffPrinGr       899164 non-null  object
#  25  GrAppv             899164 non-null  object
#  26  SBA_Appv           899164 non-null  object
# dtypes: float64(1), int64(9), object(17)
# memory usage: 185.2+ MB

# %%
df.MIS_Status.value_counts()
# Out:
# P I F     739609
# CHGOFF    157558
# Name: MIS_Status, dtype: int64

# %%
df['LoanNr_ChkDgt']
# Out:
# 0         1000014003
# 1         1000024006
# 2         1000034009
# 3         1000044001
# 4         1000054004
#              ...
# 899159    9995573004
# 899160    9995603000
# 899161    9995613003
# 899162    9995973006
# 899163    9996003010
# Name: LoanNr_ChkDgt, Length: 899164, dtype: int64

# %%
msno.matrix(df)
# Out:
# <AxesSubplot: >

# %%
mask_chgoff = ~df['ChgOffDate'].isna()
mask_chgoff_MIS = df['MIS_Status'] == 'P I F'

# %%
df[mask_chgoff&mask_chgoff_MIS]
# Out:
#         LoanNr_ChkDgt                            Name  \
# 558        1004176005                GREENLIFE MOBILE
# 850        1005925000  GILLIAN'S DELICATESSEN & CATER
# 853        1005936010  TRICAS MANAGEMENT SERVICES LLC
# 861        1005986003  CAPITAL EXPLOSION GRAPHIC DESI
# 866        1006016007   C-BARB AND CONLEY PROMOTIONAL
# ...               ...                             ...
# 895467     9913513005      INFINITE TECH. CORPORATION
# 895669     9918003004           ANRO INSULATION, INC.
# 897114     9950351001                        CLUB 191
# 897735     9963813010   J.T. AUTOMOTIVE SERVICES, LLC
# 898966     9991623009       WHEELER INVESTMENTS, INC.
#
#                              City State    Zip  \
# 558                      SAN JOSE    CA  95132
# 850                   FLORAL PARK    NY  11001
# 853                        DALLAS    TX  75218
# 861     UPPER MARLBORO (MARLBORO)    MD  20774
# 866                       HOUSTON    TX  77057
# ...                           ...   ...    ...
# 895467                 RICHARDSON    TX  75080
# 895669                   STAFFORD    VA  22554
# 897114                 PORTSMOUTH    IA  51565
# 897735                SOUTHINGTON    CT   6489
# 898966                   KENNESAW    GA  30144
#
#                                   Bank BankState   NAICS ApprovalDate  \
# 558                          BBCN BANK        CA  561730     7-Feb-06
# 850     JPMORGAN CHASE BANK NATL ASSOC        IL  722320    26-Mar-03
# 853        WELLS FARGO BANK NATL ASSOC        SD  621511     8-Feb-06
# 861                          BBCN BANK        CA  541430     8-Feb-06
# 866                          BBCN BANK        CA  421450     8-Feb-06
# ...                                ...       ...     ...          ...
# 895467                LEGACYTEXAS BANK        TX  541512    23-Jan-97
# 895669   MANUFACTURERS & TRADERS TR CO        MD  235420    24-Jan-97
# 897114                             NaN       NaN       0    24-Jul-78
# 897735   TD BANK, NATIONAL ASSOCIATION        DE       0    13-Feb-97
# 898966              BRANCH BK. & TR CO        GA  445310    26-Feb-97
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# 558          2006  ...          0       N   19-Oct-09         28-Feb-06
# 850          2003  ...          N       N   29-Mar-06         31-Mar-03
# 853          2006  ...          Y       N    2-Feb-09         31-Mar-06
# 861          2006  ...          0       N   14-Aug-12         28-Feb-06
# 866          2006  ...          0       N    1-Jun-09         28-Feb-06
# ...           ...  ...        ...     ...         ...               ...
# 895467       1997  ...          N       N   29-Dec-11         31-May-97
# 895669       1997  ...          N       Y   22-Mar-00         19-Feb-97
# 897114       1978  ...          N       N   23-Nov-88          6-Dec-78
# 897735       1997  ...          N       Y   26-Apr-06         31-May-97
# 898966       1997  ...          0       N    9-Oct-98         31-Mar-97
#
#         DisbursementGross  BalanceGross  MIS_Status ChgOffPrinGr  \
# 558            $5,000.00         $0.00        P I F   $3,330.00
# 850           $15,000.00         $0.00        P I F  $10,270.00
# 853          $165,553.00         $0.00        P I F  $97,486.00
# 861           $10,000.00         $0.00        P I F   $2,310.00
# 866            $5,000.00         $0.00        P I F   $3,783.00
# ...                   ...           ...         ...          ...
# 895467       $441,000.00         $0.00        P I F   $6,462.00
# 895669        $50,000.00         $0.00        P I F  $46,165.00
# 897114        $65,000.00         $0.00        P I F  $20,878.00
# 897735        $60,000.00         $0.00        P I F  $17,236.00
# 898966        $45,000.00         $0.00        P I F  $30,002.00
#
#               GrAppv      SBA_Appv
# 558       $5,000.00     $4,250.00
# 850      $15,000.00     $7,500.00
# 853     $100,000.00    $50,000.00
# 861      $10,000.00     $8,500.00
# 866       $5,000.00     $4,250.00
# ...              ...           ...
# 895467  $441,000.00   $330,750.00
# 895669   $50,000.00    $40,000.00
# 897114   $65,000.00    $48,750.00
# 897735   $60,000.00    $48,000.00
# 898966   $45,000.00    $36,000.00
#
# [4927 rows x 27 columns]

# %%
df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  DisbursementGross  \
# 0  ...          N       Y         NaN         28-Feb-99        $60,000.00
# 1  ...          N       Y         NaN         31-May-97        $40,000.00
# 2  ...          N       N         NaN         31-Dec-97       $287,000.00
# 3  ...          N       Y         NaN         30-Jun-97        $35,000.00
# 4  ...          N       N         NaN         14-May-97       $229,000.00
#
#    BalanceGross  MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0        $0.00        P I F       $0.00    $60,000.00    $48,000.00
# 1        $0.00        P I F       $0.00    $40,000.00    $32,000.00
# 2        $0.00        P I F       $0.00   $287,000.00   $215,250.00
# 3        $0.00        P I F       $0.00    $35,000.00    $28,000.00
# 4        $0.00        P I F       $0.00   $229,000.00   $229,000.00
#
# [5 rows x 27 columns]

# %%
df['MIS_Status'].value_counts()
# Out:
# P I F     739609
# CHGOFF    157558
# Name: MIS_Status, dtype: int64

# %%
X = df.copy()

# %%
X = X.drop(columns=['Name', 'LoanNr_ChkDgt', 'Bank', 
                     'BankState', 'DisbursementDate', 'ApprovalDate', 
                    'ApprovalFY', 'FranchiseCode', 'Zip', 'City', 'State', 'ChgOffDate', 'SBA_Appv'])

# %%
X=X.dropna()

# %%
columns = ['DisbursementGross','BalanceGross','ChgOffPrinGr','GrAppv']
for column in columns: 
    X[column] = X[column].str.replace('$', '').str.replace(',','').str.strip()
# Out:
# /tmp/ipykernel_68791/4055596084.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X[column] = X[column].str.replace('$', '').str.replace(',','').str.strip()

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889938 entries, 0 to 899163
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   NAICS              889938 non-null  int64
#  1   Term               889938 non-null  int64
#  2   NoEmp              889938 non-null  int64
#  3   NewExist           889938 non-null  float64
#  4   CreateJob          889938 non-null  int64
#  5   RetainedJob        889938 non-null  int64
#  6   UrbanRural         889938 non-null  int64
#  7   RevLineCr          889938 non-null  object
#  8   LowDoc             889938 non-null  object
#  9   DisbursementGross  889938 non-null  object
#  10  BalanceGross       889938 non-null  object
#  11  MIS_Status         889938 non-null  object
#  12  ChgOffPrinGr       889938 non-null  object
#  13  GrAppv             889938 non-null  object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 101.8+ MB

# %%
X[columns] = X[columns].astype('float64').astype('int64')

# %%
values = ['0','T','1','R','`','2','C','3',',','7','A','5','.','4','-','Q']
X = X[X.RevLineCr.isin(values) == False]

# %%
values = ['0','C','S','A','R','1']
X = X[X.LowDoc.isin(values) == False]

# %%
cat = ['RevLineCr', 'LowDoc']

# %%
X = X.drop('NAICS', axis =1)

# %%
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures, StandardScaler, RobustScaler
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import numpy as np
from scipy.stats import kruskal
from sklearn.model_selection import cross_validate

# %%
X.columns
# Out:
# Index(['Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'UrbanRural',
#        'RevLineCr', 'LowDoc', 'DisbursementGross', 'BalanceGross',
#        'MIS_Status', 'ChgOffPrinGr', 'GrAppv'],
#       dtype='object')

# %%
y = X['MIS_Status'].astype('category').cat.codes
X = X.drop(['MIS_Status'], axis=1)

num = list(X.select_dtypes(include=['int', 'float']).columns)

# %%
num
# Out:
# ['Term',
#  'NoEmp',
#  'NewExist',
#  'CreateJob',
#  'RetainedJob',
#  'UrbanRural',
#  'DisbursementGross',
#  'BalanceGross',
#  'ChgOffPrinGr',
#  'GrAppv']

# %%
std = StandardScaler()
ohe = OneHotEncoder()

preprocessor = make_column_transformer(
    (ohe, cat),
    (std, num)
)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42, stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(class_weight='balanced')
rfc_pipe = make_pipeline(preprocessor, rfc)

rfc_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['RevLineCr', 'LowDoc']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['Term', 'NoEmp', 'NewExist',
#                                                    'CreateJob', 'RetainedJob',
#                                                    'UrbanRural',
#                                                    'DisbursementGross',
#                                                    'BalanceGross',
#                                                    'ChgOffPrinGr',
#                                                    'GrAppv'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(class_weight='balanced'))])

# %%
rfc_pipe.score(X_test, y_test)
# Out:
# 0.9931671764169975

# %%
import seaborn as sns

# %%
x_to_plot = rfc_pipe[-1].feature_importances_
y_to_plot = rfc_pipe[:-1].get_feature_names_out()

sns.barplot(x=x_to_plot,y=y_to_plot)
# Out:
# <AxesSubplot: >

# %%
X.columns
# Out:
# Index(['Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'UrbanRural',
#        'RevLineCr', 'LowDoc', 'DisbursementGross', 'BalanceGross',
#        'ChgOffPrinGr', 'GrAppv'],
#       dtype='object')

# %%
X = X.drop('ChgOffPrinGr', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.1, random_state=42, stratify=y)

# %%
num.remove('ChgOffPrinGr')

rfc_pipe.fit(X_train, y_train)
x_to_plot = rfc_pipe[-1].feature_importances_
y_to_plot = rfc_pipe[:-1].get_feature_names_out()

sns.barplot(x=x_to_plot,y=y_to_plot)
# Out:
# <AxesSubplot: >

# %%
rfc_pipe.score(X_test, y_test)
# Out:
# 0.9221220797813496

# %%
pred = rfc_pipe.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78     10247
#            1       0.96      0.94      0.95     51221
#
#     accuracy                           0.92     61468
#    macro avg       0.85      0.88      0.86     61468
# weighted avg       0.93      0.92      0.92     61468

# %%
sns.boxplot(data=df, x='Term', y='MIS_Status')
# Out:
# <AxesSubplot: xlabel='Term', ylabel='MIS_Status'>

# %%
import pickle
pickle.dump(rfc_pipe, open('rfc.sav', 'wb'))

# %%
X_train
# Out:
#         Term  NoEmp  NewExist  CreateJob  RetainedJob  UrbanRural RevLineCr  \
# 48666     84     45       1.0          0            0           0         N
# 659834    72      3       1.0          0            3           2         Y
# 670939   300      5       1.0          0            0           0         N
# 660659    66      5       1.0          0            0           1         N
# 673288    60     10       1.0          0           10           1         Y
# ...      ...    ...       ...        ...          ...         ...       ...
# 287665    48     20       1.0          0            0           0         N
# 339966    60      2       2.0          0            0           0         N
# 540052   240     10       1.0         10            0           0         N
# 689847   300      7       1.0          0            0           0         N
# 773579   120      8       1.0          0            0           0         N
#
#        LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv
# 48666       N             170000             0  170000    127500
# 659834      N              25000             0   25000     12500
# 670939      N             520000             0  520000    390000
# 660659      N              60000             0   60000     51000
# 673288      N              51500             0   50000     25000
# ...       ...                ...           ...     ...       ...
# 287665      N              65000             0   65000     58500
# 339966      N              18000             0   18000     16200
# 540052      N             200000             0  200000    200000
# 689847      N             700000             0  720000    540000
# 773579      N             130000             0  130000    117000
#
# [553212 rows x 12 columns]

# %%
X_train.iloc[0].values
# Out:
# array([84, 45, 1.0, 0, 0, 0, 'N', 'N', 170000, 0, 170000, 127500],
#       dtype=object)

# %%
y_train[0]
# Out:
# 1

# %%
# Out:
# array([0, 1], dtype=int8)

# %%
X_train.columns
# Out:
# Index(['Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'UrbanRural',
#        'RevLineCr', 'LowDoc', 'DisbursementGross', 'BalanceGross', 'GrAppv',
#        'SBA_Appv'],
#       dtype='object')

# %%
rfc_pipe.predict(pd.DataFrame(dict(zip(list(X_train.columns), X_train.iloc[0].values)), index=[0])
   
)
# Out:
# array([1], dtype=int8)

# %%
X_train.iloc[0].values
# Out:
# array([84, 45, 1.0, 0, 0, 0, 'N', 'N', 170000, 0, 170000, 127500],
#       dtype=object)
